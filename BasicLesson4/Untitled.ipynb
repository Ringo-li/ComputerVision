# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import cv2

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Worklog\\Projects\\ComputerVision\\BasicLesson4'

# %%
cv2.__version__
# Out:
# '4.8.0'

# %%
img = cv2.imread('img/cat.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1253, 1880, 3)

# %%
plt.imshow(img)

# %%
img_fixed = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_fixed)

# %%
img_gray = cv2.imread('img/cat.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img_fixed.shape
# Out:
# (1253, 1880, 3)

# %%
img_resize = cv2.resize(img_fixed, (1000,500))

# %%
plt.imshow(img_resize)

# %%
img_flip = cv2.flip(img_fixed,1)

# %%
plt.imshow(img_flip)

# %%
img_save = cv2.cvtColor(img_flip, cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite('./img/img_flip.jpg', img_save)
# Out:
# True

# %%
a = img_gray[0]
b = img_fixed[0]

# %%
a,b
# Out:
# (array([93, 93, 93, ..., 99, 98, 97], dtype=uint8),
#  array([[111,  88,  70],
#         [111,  88,  70],
#         [111,  88,  70],
#         ...,
#         [193,  51,  99],
#         [195,  49,  98],
#         [195,  47,  97]], dtype=uint8))

# %%
i = 1800
print(a[i])
print(0.2989 * b[i][0] + 0.5870 * b[i][1] + 0.1140 * b[i][2])
# Out:
# 144
# 144.1365
